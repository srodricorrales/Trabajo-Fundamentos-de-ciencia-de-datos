# %% [markdown]
# # Bitacora de aprendizaje en algoritmos de python

# %% [markdown]
# Hoy 3 de mayo de 2022 he podido avanzar con mis estudios de algoritmia en python. 7,9 puntos de 10 para iniciar
# y para lo que pudiste avanzar es bueno. Ahora toca retomar varios temas que si es posible ensayar cargando archivos
# para aplicarlo en el estado de importaciones de Promather.
#
# Dentro de los tópicos a ver es hacer estudio en profundidad al tema de eficiencia en la algoritmia ,
# por lo que la meta a corto plazo es hacer un intensivo del estudio de esta parte.

# %% [markdown]
# ¿ Da igual cualquier algoritmo ?
#
# Viendo el ejemplo de la ultima clase hay una diferencia en terminos de tiempo de rendimiento. Al comparar la
# funcion sort vs def 'ordenar(lista)' demuestra el costo de tiempo de que una es mas eficiente. La diferencia clave es
# ver la cantidad de tareas que se realiza para una tarea a programar dentro de la secuencia de tareas.

# %%
from PIL import Image # PIL : Python image library

# %%
im = Image.open('ejemplo6-1.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1152x720 at 0x2A214A94760>

# %% [markdown]
# El Merge Sort le esta dando al procesador menos instrucciones a realizar. Es un algoritmo que define a un vector
# dividiendo para conquistar. Ejemplo , tengo un vector o lista , voy a dividir la lista en 2 , despues ordenarlas ,
# finalmente despues de ordenarlas se mezclan , esto recursivamente sucede hacia abajo del codigo.

# %%
im2 = Image.open('ejemplo6-2.jpg')
im2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x720 at 0x2A214CF12E0>

# %% [markdown]
# ## Análisis espacial de algoritmos

# %%
T(n) va a decir cuantas instrucciones voy a necesitar. por ejemplo
selection sort
for i = 0 in n-1
   for j = i + 1 in n
    if lista [j] < lista[i]
    intercambiar(lista[i], lista[j])
    #fin para condicion if
   #fin para ciclo for 
#fin para ciclo for

# %% [markdown]
# En este caso analizar que el que el algoritmo crece cuadraticamente o(n2) porque hay 2 ciclos que dependen de n.
# Otro podria ser otro ejemplo:

# %%
    for i=0 in n
       for j=0 in 15 

El crecimiento seria lineal o(n)

# %% [markdown]
# Estas consdireaciones que hemos realizado corresponde a analisis asintotico de algoritmo, en este de analisis temporal
# de algoritmos. Predecir que tenedencia va a tener la funcion que me dice cuantas instruciones ejecutar en funcion de
# la entrada.

# %% [markdown]
# nos queremos quedar con el que tenga menor tiempo de rendimiento, esto basado que la mejor opcion seria lineal ante
# las cuadraticas.
